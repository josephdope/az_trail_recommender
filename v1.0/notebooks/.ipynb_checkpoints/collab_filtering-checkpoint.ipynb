# %% [markdown]
# ### Collaborative Filtering Trail Recommender

# %% [markdown]
# For this recommendation system, the reviews of all trails were gathered and used to predict the ratings of trails that a user has not rated yet. By doing so, we are able to recommend a trail to a user based on our predicted rating.

# %% [markdown]
# #### Where is the data coming from?

# %% [markdown]
# The data was scraped from AllTrails.com using BeautifulSoup and Selenium. A list of 1418 trails in Arizona was gathered. The reviews of each trail were then collected and exported to a SQL database. This was a bit challenging, as the only way to load more reviews was to click a button that would populate more reviews. This action would load 30 more reviews each time, so it had to be done repeatedly. As such, Selenium was used to located the button on click it (total reviews/30) times. For this demonstration, the class created to extract the data from the webpages will not be used. The data will be imported from the SQL database

# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2

conn = psycopg2.connect("dbname='az_trail_recommender' user='josephdoperalski' host='localhost'")
cur = conn.cursor()
query_reviews = '''SELECT * FROM trail_reviews'''
reviews = sqlio.read_sql_query(query_reviews, conn)
reviews.drop('index', axis = 1, inplace = True)
reviews.head(10)
# Out:
# /anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
#   review_id  trail_id                                trail_name  \
# 0       0_0         0  Camelback Mountain via Echo Canyon Trail
# 1       0_1         0  Camelback Mountain via Echo Canyon Trail
# 2       0_2         0  Camelback Mountain via Echo Canyon Trail
# 3       0_3         0  Camelback Mountain via Echo Canyon Trail
# 4       0_4         0  Camelback Mountain via Echo Canyon Trail
# 5       0_5         0  Camelback Mountain via Echo Canyon Trail
# 6       0_6         0  Camelback Mountain via Echo Canyon Trail
# 7       0_7         0  Camelback Mountain via Echo Canyon Trail
# 8       0_8         0  Camelback Mountain via Echo Canyon Trail
# 9       0_9         0  Camelback Mountain via Echo Canyon Trail
#
#                        user rating  \
# 0    /members/arron-hampton      5
# 1   /members/brian-white-18      4
# 2    /members/arron-hampton      5
# 3    /members/maddie-wilson      5
# 4  /members/giselle-johnson      5
# 5  /members/mark-mckeever-1      5
# 6     /members/shaun-otoole      5
# 7       /members/katie-plew      5
# 8   /members/ronald-catague      5
# 9  /members/wissam-baghdadi      5
#
#                                                 body
# 0  Super hard. It’s all scrambling after about 1/...
# 1  First time hiking this trail and it did not di...
# 2  A must do for the 360 degree views of the Vall...
# 3                          Very challenging and fun!
# 4  Went when it was slightly rainy and enjoyed th...
# 5  Very nice hike. At 62, it was a challenge. Saw...
# 6  Amazing Trail. More treacherous than the photo...
# 7           Great workout definitely worth the view!
# 8  physically demanding and definitely not for fi...
# 9  I started at 10:30 am, I was surprised to see ...

# %% [markdown]
# From here, some manipulation had to be done. The review_id, trail_name, and body all had to be dropped. This is done as the model used to create our recommendation engine only requires the trail_id, user, and rating. The user column was also altered so as to remove the '/members/' in front of the usernames. Running the cell below outputs the format for the dataframe that will be fed into the model.

# %%
import sys
sys.path.append('..')
from hiking_data_v1 import ReviewsShaper

rev_shaper = ReviewsShaper(reviews)
rev_shaper.fix_column_data()
rev_shaper.user2user()
df = rev_shaper.user2user_df
df.head(20)
# Out:
#                  user  trail_id  rating
# 0              007297        14     5.0
# 1         0scararn0ld        39     5.0
# 2         0scararn0ld       311     5.0
# 3   101southdrum-user       584     5.0
# 4          1337killer       248     5.0
# 5              139ss6        25     5.0
# 6            1433jenn      1479     4.0
# 7           14burrito         0     5.0
# 8           14burrito        22     4.0
# 9           14burrito        94     4.0
# 10          14burrito       361     5.0
# 11          14burrito       383     5.0
# 12          14burrito       526     5.0
# 13          14burrito      1017     5.0
# 14          14burrito      1129     5.0
# 15          14burrito      1164     5.0
# 16          14burrito      1287     4.0
# 17          14erbound         0     4.0
# 18          14erbound         3     5.0
# 19          14erbound         4     2.0

# %% [markdown]
# #### How are recommendations made?

# %% [markdown]
# Let's take a step back. The point of this model is to predict the ratings for trails that a user has not yet rated. It does this by using information about how a given user has rated other trails and how a given trail is rated by other users. Our actual matrix would be a sparse matrix as there would be a lot of unknown values. It would look something like the one below.

# %%
sparse_mat = df.groupby(['user', 'trail_id'], as_index=False).agg({'rating':'mean'}).pivot('user', 'trail_id', 'rating')
print(" matrix shape:", sparse_mat.shape, "\n", "missing values:",sum(sparse_mat.isnull().sum()))
sparse_mat.head(20)
# Out:
#  matrix shape: (34878, 1414)
#  missing values: 49247057
# trail_id                  0     1     2     3     4     5     6     7     \
# user
# 007297                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0scararn0ld                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 101southdrum-user          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1337killer                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 139ss6                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1433jenn                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14burrito                  5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14erbound                  4.0   NaN   NaN   5.0   2.0   NaN   NaN   NaN
# 15-dollars-40-dollars      5.0   NaN   NaN   NaN   5.0   NaN   NaN   NaN
# 1800asphalt                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1mary                      4.0   NaN   NaN   NaN   NaN   NaN   5.0   NaN
# 1mehtaster                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1soldierforlife-williams   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 209taro                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 24lupo                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2922ml                     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2btowed                    NaN   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2hikers-flores             NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN
# 2pollyedwards              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2worldtravelers-thecw      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# trail_id                  8         9     ...   1862  1863  1864  1865  1866  \
# user                                      ...
# 007297                     NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 0scararn0ld                NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 101southdrum-user          NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 1337killer                 NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 139ss6                     NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 1433jenn                   NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 14burrito                  NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 14erbound                  NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 15-dollars-40-dollars      NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 1800asphalt                NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 1mary                      NaN  4.333333  ...    NaN   NaN   NaN   NaN   NaN
# 1mehtaster                 NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 1soldierforlife-williams   NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 209taro                    5.0       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 24lupo                     NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 2922ml                     NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 2btowed                    NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 2hikers-flores             NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 2pollyedwards              NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 2worldtravelers-thecw      NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
#
# trail_id                  1867  1868  1869  1870  1871
# user
# 007297                     NaN   NaN   NaN   NaN   NaN
# 0scararn0ld                NaN   NaN   NaN   NaN   NaN
# 101southdrum-user          NaN   NaN   NaN   NaN   NaN
# 1337killer                 NaN   NaN   NaN   NaN   NaN
# 139ss6                     NaN   NaN   NaN   NaN   NaN
# 1433jenn                   NaN   NaN   NaN   NaN   NaN
# 14burrito                  NaN   NaN   NaN   NaN   NaN
# 14erbound                  NaN   NaN   NaN   NaN   NaN
# 15-dollars-40-dollars      NaN   NaN   NaN   NaN   NaN
# 1800asphalt                NaN   NaN   NaN   NaN   NaN
# 1mary                      NaN   NaN   NaN   NaN   NaN
# 1mehtaster                 NaN   NaN   NaN   NaN   NaN
# 1soldierforlife-williams   NaN   NaN   NaN   NaN   NaN
# 209taro                    NaN   NaN   NaN   NaN   NaN
# 24lupo                     NaN   NaN   NaN   NaN   NaN
# 2922ml                     NaN   NaN   NaN   NaN   NaN
# 2btowed                    NaN   NaN   NaN   NaN   NaN
# 2hikers-flores             NaN   NaN   NaN   NaN   NaN
# 2pollyedwards              NaN   NaN   NaN   NaN   NaN
# 2worldtravelers-thecw      NaN   NaN   NaN   NaN   NaN
#
# [20 rows x 1414 columns]

# %% [markdown]
# Ugly, right? While this is a truncated version, There are actually 34878 rows, which would represent 34878 users and 1414 columns representing the trails. In all, 49247057 of the 49317492 values are missing, which represents more than 99% of the matrix. This is more sparse than we'd like. Making predictions with this many unknown values would not be reliable. The histograms below show that the vast majority of users have left very few reviews and that many trails have very few ratings. For the sake of a reliable recommendation, we'll remove those users that have had less than 5 reviews and trails with less than 10 reviews. For those users and trails, we would face the cold start problem and a content-based recommendation system would be more appropriate.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

user_ratings_count = df.groupby('user', as_index=False).agg({'rating':'count'})
trail_ratings_count = df.groupby('trail_id', as_index=False).agg({'rating':'count'})
print("median ratings:", ratings_count['rating'].median())
fig, axs = plt.subplots(1, 2, figsize = (18, 5))
axs[0].hist(user_ratings_count['rating'], bins = 100)
axs[0].set_title('user ratings histogram')
axs[1].hist(trail_ratings_count['rating'], bins = 100)
axs[1].set_title('trail ratings histogram')
plt.show()
# Out:
# median ratings: 1.0

# %%
final_df = df[(df['user'].isin(user_ratings_count[user_ratings_count['rating'] >= 5]['user'])) & (df['trail_id'].isin(trail_ratings_count[trail_ratings_count['rating'] >= 10]['trail_id']))]

# %%
sparse_final = final_df.groupby(['user', 'trail_id'], as_index=False).agg({'rating':'mean'}).pivot('user', 'trail_id', 'rating')
print(" matrix shape:", sparse_final.shape)
sparse_final.head(20)
# Out:
#  matrix shape: (2623, 905)
# trail_id                  0     1     2     3     4     5     6     7     \
# user
# 14burrito                  5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14erbound                  4.0   NaN   NaN   5.0   2.0   NaN   NaN   NaN
# 1mary                      4.0   NaN   NaN   NaN   NaN   NaN   5.0   NaN
# 4billh                     NaN   NaN   NaN   NaN   NaN   5.0   5.0   NaN
# 7shan                      NaN   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# a-alioto                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# a-ba                       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# a-g-96                     5.0   5.0   NaN   NaN   NaN   NaN   NaN   5.0
# aaron-cook-18              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# aaron-helvig               NaN   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# aaron-kes                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# aaron-schram-1             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# aaron-taylor-9066          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# aaron-walp                 NaN   NaN   5.0   NaN   NaN   NaN   NaN   NaN
# abbi-marx                  4.0   NaN   NaN   NaN   5.0   NaN   NaN   NaN
# abby-barenholtz            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abdul-tawab-kawa-saljuqi   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abe-gold-3                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abraham-negrete            4.0   4.0   NaN   5.0   5.0   NaN   NaN   NaN
# adalberto-granillo         NaN   NaN   NaN   NaN   5.0   NaN   NaN   NaN
#
# trail_id                  8         9     ...   1615  1623  1663  1667  1670  \
# user                                      ...
# 14burrito                  NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 14erbound                  NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 1mary                      NaN  4.333333  ...    NaN   NaN   NaN   NaN   NaN
# 4billh                     NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# 7shan                      NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# a-alioto                   NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# a-ba                       5.0       NaN  ...    NaN   NaN   NaN   NaN   NaN
# a-g-96                     NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# aaron-cook-18              NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# aaron-helvig               NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# aaron-kes                  NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# aaron-schram-1             NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# aaron-taylor-9066          NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# aaron-walp                 NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# abbi-marx                  NaN  5.000000  ...    NaN   NaN   NaN   NaN   NaN
# abby-barenholtz            4.0       NaN  ...    NaN   NaN   NaN   NaN   NaN
# abdul-tawab-kawa-saljuqi   NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# abe-gold-3                 NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# abraham-negrete            NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
# adalberto-granillo         NaN       NaN  ...    NaN   NaN   NaN   NaN   NaN
#
# trail_id                  1689  1701  1702  1754  1862
# user
# 14burrito                  NaN   NaN   NaN   NaN   NaN
# 14erbound                  NaN   NaN   NaN   NaN   NaN
# 1mary                      NaN   NaN   NaN   NaN   NaN
# 4billh                     NaN   NaN   NaN   NaN   NaN
# 7shan                      NaN   NaN   NaN   NaN   NaN
# a-alioto                   NaN   NaN   NaN   NaN   NaN
# a-ba                       NaN   NaN   NaN   NaN   NaN
# a-g-96                     NaN   NaN   NaN   NaN   NaN
# aaron-cook-18              NaN   NaN   NaN   NaN   NaN
# aaron-helvig               NaN   NaN   NaN   NaN   NaN
# aaron-kes                  NaN   NaN   NaN   NaN   NaN
# aaron-schram-1             NaN   NaN   NaN   NaN   NaN
# aaron-taylor-9066          NaN   NaN   NaN   NaN   NaN
# aaron-walp                 NaN   NaN   NaN   NaN   NaN
# abbi-marx                  NaN   NaN   NaN   NaN   NaN
# abby-barenholtz            NaN   NaN   NaN   NaN   NaN
# abdul-tawab-kawa-saljuqi   NaN   NaN   NaN   NaN   NaN
# abe-gold-3                 4.0   NaN   NaN   NaN   NaN
# abraham-negrete            NaN   NaN   NaN   NaN   NaN
# adalberto-granillo         NaN   NaN   NaN   NaN   NaN
#
# [20 rows x 905 columns]

# %% [markdown]
# That's a little bit better, but not much. We'll work with what we've got. We now have our original matrix, which we will call A, of size n $\times$ d . This matrix can actually be represented as the dot product of three smaller matrices that we'll denote with U, sigma, and V<sup>T</sup>. This is known as SVD. Briefly, U is a matrix representing user trends, sigma is a diagonal matrix of singular values (useful for determing how much information is actually necessary), and V<sup>T</sup> is a matrix of trends of trails. Therefore A = U $\times$ sigma $\times$ V<sup>T</sup>. For simplicity, we'll merge sigma into either U or V<sup>T</sup> so we now have A = U $\times$ V<sup>T</sup>. In order to predict ratings, we make this an optimization problem so that we are minimzing $\sum$(r<sub>ui</sub> -  p<sub>u</sub> $\times$ q<sub>i</sub>)<sup>2</sup>, where r represents the actual ratings, p represents a vector from U and q represents a vector from V<sup>T</sup>. Essentially, this is done by iteratively updating the values for p<sub>u</sub> and q<sub>i</sub> using stochastic gradient descent until a certain predecided threshold is reached.

# %% [markdown]
# <img src="https://intoli.com/blog/pca-and-svd/img/svd-matrices.png" >

# %% [markdown]
# Unknown values can then be inserted into our model. The specific model used for this project is SVD from the suprise module. The model was fit on the above data for each user and trail combination where a rating was present. Cells that had a missing value were fed into the model for a prediction. The output for the model is then a sorted list of trails with the highest predicted ratings for trails not yet rated by the user.
